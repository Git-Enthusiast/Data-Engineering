# %% [markdown]
# # 🐍 Python Lists — Complete Guide
#
# This notebook covers **every important concept** about Python Lists, split into individual cells for clarity.
#
# ---
#
# ## Topics Covered
# 1. What is a List?
# 2. Creating Lists
# 3. Accessing Elements (Indexing)
# 4. Slicing Lists
# 5. Iterating Lists
# 6. List Operations (Concatenation, Repetition, Membership, Length)
# 7. Aggregate Functions — min(), max(), sum()
# 8. Modifying Lists (add / change / remove elements)
# 9. Important List Methods (sort, reverse, count, index, copy, extend)
# 10. Nested Lists
# 11. List Comprehensions
# 12. Converting Other Iterables to List
# 13. Copying Lists — Shallow vs Deep Copy
# 14. Quick Summary

# %% [markdown]
# ---
# ## 1️⃣ What is a List?
#
# A **list** is one of Python's most versatile built-in data structures.
#
# | Property | Details |
# |---|---|
# | **Mutable** | Elements can be changed after creation |
# | **Ordered** | Elements maintain insertion order |
# | **Indexed** | First element is at index `0` |
# | **Allows Duplicates** | Same value can appear multiple times |
# | **Heterogeneous** | Can store `int`, `float`, `str`, `bool`, other lists, etc. |
#
# Syntax: `my_list = [item1, item2, item3]`

# %% [markdown]
# ---
# ## 2️⃣ Creating Lists
#
# Lists can be created in multiple ways:
# - Using square brackets `[]`
# - Using the `list()` constructor (converts other iterables like tuples, strings, etc.)
# - An empty list is created using `[]` or `list()`

# %%
# ============================================
# 2️⃣ Creating Lists
# ============================================

# Empty list — no elements yet
myList = []
print("Empty list:", myList)          # []

# List with integer elements
numbers = [1, 2, 3, 4, 5]
print("Numbers:", numbers)            # [1, 2, 3, 4, 5]

# List with string elements
fruits = ["apple", "banana", "cherry"]
print("Fruits:", fruits)             # ['apple', 'banana', 'cherry']

# Mixed list — different data types in one list
mixed = [1, "apple", 3.14, True]
print("Mixed:", mixed)               # [1, 'apple', 3.14, True]

# Using list() constructor — converts a tuple into a list
numbers2 = list((10, 20, 30))
print("From tuple:", numbers2)       # [10, 20, 30]

print(type(mixed))  # To find data types of list
print(type(myList))
another_list = list()   # Used to create empty list
print(another_list)
print(type(another_list))

""" 
Note: List and array are not same.
    array: Stores data of similar type
    list: Stores data of different types

How to implement arrya ? 
    by using array module consisting array class
    by using numpy package also consisting array class

"""
# Out:
# Empty list: []
# Numbers: [1, 2, 3, 4, 5]
# Fruits: ['apple', 'banana', 'cherry']
# Mixed: [1, 'apple', 3.14, True]
# From tuple: [10, 20, 30]
# <class 'list'>
# <class 'list'>
# []
# <class 'list'>
# ' \nNote: List and array are not same.\n    array: Stores data of similar type\n    list: Stores data of different types\n\nHow to implement arrya ? \n    by using array module consisting array class\n    by using numpy package also consisting array class\n\n'

# %% [markdown]
# # Accessing Elements in list
# Two ways:-
#     `1. Indexing`
#     `2. Slicing`
#
# **Indexing** : Used to access individual (single) element of list.
# **Slicing** : Used to access group of elements of a list. We can access range of elements using slicing.

# %% [markdown]
# ---
# ### 3️⃣ Accessing Elements (Indexing)
#
# Python lists are **zero-indexed** — the first element is at index `0`.
#
# - **Positive indexing**: starts from the left → `0, 1, 2, ...`
# - **Negative indexing**: starts from the right → `-1, -2, -3, ...`
#   - `-1` always refers to the **last** element
#
# ```
# fruits = ["apple", "banana", "cherry"]
# Index:      0         1         2
# Neg Index: -3        -2        -1
# ```

# %%
# ============================================
# 3️⃣ Accessing Elements — Indexing
# ============================================

fruits = ["apple", "banana", "cherry"]

# Positive indexing — counts from the start (left)
print(fruits[0])   # apple  → first element
print(fruits[2])   # cherry → third element

# Negative indexing — counts from the end (right)
print(fruits[-1])  # cherry → last element
print(fruits[-2])  # banana → second from last
# Out:
# apple
# cherry
# cherry
# banana

# %% [markdown]
# ---
# ### 4️⃣ Slicing Lists
#
# Slicing lets you extract a **sub-list** (portion) from a list.
#
# **Syntax:** `list[start : stop : step]`
#
# | Parameter | Meaning |
# |---|---|
# | `start` | Index to begin from (inclusive). Default = `0` |
# | `stop` | Index to stop at (**exclusive** — last index NOT included). Default = end of list |
# | `step` | Jump every `step` elements. Default = `1`. Negative step reverses direction |
#
# > 💡 `step = -1` reverses the list

# %%
# ============================================
# 4️⃣ Slicing Lists
# Syntax: list[start : stop : step]
# ============================================

numbers = [10, 20, 30, 40, 50, 60]

# [start:stop] — returns elements from index 1 up to (not including) index 4
print(numbers[1:4])   # [20, 30, 40]

# [:stop] — start defaults to 0; goes up to index 2 (index 3 excluded)
print(numbers[:3])    # [10, 20, 30]

# [start:] — starts at index 3 and goes to the end
print(numbers[3:])    # [40, 50, 60]

# [::step] — start=0, stop=end, step=2 → every 2nd element
print(numbers[::2])   # [10, 30, 50]

# [::-1] — negative step reverses the entire list
print(numbers[::-1])  # [60, 50, 40, 30, 20, 10]
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [40, 50, 60]
# [10, 30, 50]
# [60, 50, 40, 30, 20, 10]

# %% [markdown]
# # Length of Lists
#     Two methods:
#     `1. using len(list) function`
#     `2. by Manual Ways`

# %%
list_1 = [12,12,0,-454,"Rajan",2+4j,23.344]
print(len(list_1))  # Using len() Function 

# Manual Way
count = 0
for item in list_1:
    count += 1
print(f"The length of the list is: {count}" )
# Out:
# 7
# The length of the list is: 7

# %% [markdown]
# ---
# ## 5️⃣ Iterating Lists
#
# You can loop through a list using:
#
# | Method | Use Case |
# |---|---|
# | `for item in list` | Simple loop — access each element |
# | `enumerate(list, start=N)` | Loop with both **index** and **value** |
# | `while` loop | When you need manual index control |
#
# **`enumerate(iterable, start=0)`**: returns `(index, value)` pairs. The `start` parameter sets the starting index number (default is `0`).

# %%
# ============================================
# 5️⃣ Iterating Lists
# ============================================

fruits = ["apple", "banana", "cherry"]

# --- Method 1: Simple for loop ---
# Iterates through each element directly
print("--- for loop ---")
for fruit in fruits:
    print(fruit)   # apple, banana, cherry

# --- Method 2: enumerate() — gives index + value ---
# start=1 means the counter starts from 1 (not 0)
print("\n--- enumerate() ---")
for index, fruit in enumerate(fruits, start=1):
    print(index, fruit)   # 1 apple, 2 banana, 3 cherry

# --- Method 3: while loop with manual index ---
# Useful when you need more control over iteration
print("\n--- while loop ---")
i = 0
while i < len(fruits):      # len(fruits) = 3
    print(fruits[i])        # apple, banana, cherry
    i += 1                  # increment index manually
# Out:
# --- for loop ---
# apple
# banana
# cherry
#
# --- enumerate() ---
# 1 apple
# 2 banana
# 3 cherry
#
# --- while loop ---
# apple
# banana
# cherry

# %% [markdown]
# ---
# ## 6️⃣ List Operations
#
# Python lists support several built-in operators:
#
# | Operator | Symbol | Description |
# |---|---|---|
# | **Concatenation** | `+` | Joins two lists into a **new** list |
# | **Repetition** | `*` | Repeats the list `n` times |
# | **Membership** | `in` / `not in` | Checks if an element exists in the list → returns `True` / `False` |
# | **Length** | `len()` | Returns the number of elements |
#
# > 💡 `+` creates a **new** list; original lists remain unchanged.

# %%
# ============================================
# 6️⃣ List Operations
# ============================================

list1 = [1, 2]
list2 = [3, 4]

# --- Concatenation (+) ---
# Creates a BRAND NEW list; list1 and list2 remain unchanged
combined = list1 + list2
print("Concatenation:", combined)   # [1, 2, 3, 4]

# --- Repetition (*) ---
# Repeats list1 three times into a new list
print("Repetition:", list1 * 3)     # [1, 2, 1, 2, 1, 2]

# --- Membership (in / not in) ---
# Checks whether a value exists inside the list
print(2 in list1)       # True  → 2 IS in list1
print(5 not in list2)   # True  → 5 is NOT in list2

# --- Length (len()) ---
# Returns total number of elements in the list
print("Length:", len(list1))  # 2
# Out:
# Concatenation: [1, 2, 3, 4]
# Repetition: [1, 2, 1, 2, 1, 2]
# True
# True
# Length: 2

# %% [markdown]
# ---
# ## 7️⃣ Aggregate Functions — min(), max(), sum()
#
# Python provides built-in aggregate functions that work on numeric lists:
#
# | Function | Description |
# |---|---|
# | `min(list, key, default)` | Returns the **smallest** element  Here key is optional(basis for comparision) and default (default value is given  iterable is empty) - it is also optional|
# | `max(list, key, default)` | Returns the **largest** element Here key is optional(basis for comparison) and default (default value is given  iterable is empty)- it is also optional|
# | `sum(list)` | Returns the **total sum** of all elements |
#
# > These functions only work on lists containing comparable elements (e.g., all numbers).

# %%
# ============================================
# 7️⃣ Aggregate Functions — min(), max(), sum()
# ============================================

list2 = [9, 7, 1, 2]
list_2 = ["rajan","raj","ajay","Python","list"]

# min() — returns the smallest value in the list
print("min:", min(list2))   
print("min:", min(list_2)) 

# max() — returns the largest value in the list
print("max:", max(list_2 , key= len))   # key works on string only
print("max:", max(list_2, key= len))    # Now comparison based on length of each string element
print("max:", max(list2))    

# sum() — returns the total sum of all elements
print("sum:", sum(list2))   
#   print("sum:", sum(list_2))
# Out:
# min: 1
# min: Python
# max: Python
# max: Python
# max: 9
# sum: 19

# %%
# find maximum and minimum using manual method
nums = [45,78,12,46,98,66,53,21,63,87,89,91]
max = nums[0]
min = nums[0]

for items in nums:
    if items > max:
        max = items
print(f"The maximum element is: {max}")

for items in nums:
    if items < min:
        min = items
print(f"The minimum element is : {min}")
# Out:
# The maximum element is: 98
# The minimum element is : 12

# %% [markdown]
# ---
# ## 8️⃣ Modifying Lists (Add / Change / Remove)
#
# Since lists are **mutable**, you can modify them after creation.
#
# | Operation | Method/Syntax | Description |
# |---|---|---|
# | Change element | `list[index] = value` | Replace existing element by index |
# | Add to end | `list.append(value)` | Adds a single element at the end and here item can be of any type i.e. list, tuple, string, set, dict etc and also it does not return anything rather modifies the list|
# | Add at position | `list.insert(index, value)` | Inserts element at a specific index |
# | Remove by value | `list.remove(value)` | Removes the **first** occurrence of value |
# | Remove by index | `list.pop(index)` | Removes element at index and **returns** it. Default: last element |
# | Delete by index | `del list[index]` | Deletes element at given index |
# | Clear all | `list.clear()` | Removes **all** elements; list becomes `[]` |
# | Delete complete list | `del list_name` | Deletes list entirely so when we again want to access it it will through NameError - not found |

# %%
# ============================================
# 8️⃣ Modifying Lists — Add / Change / Remove
# ============================================

fruits = ["apple", "banana", "cherry"]

# --- Changing / Replacing an element ---
# Replace element at index 1 with "blueberry"
fruits[1] = "blueberry"
print(fruits)              # ['apple', 'blueberry', 'cherry']

# --- Adding elements ---
fruits.append("orange")   # append() → adds 'orange' at the END
print(fruits.append("orange") ) # none - as it doesn't return anything
fruits.insert(1, "kiwi")  # insert(index, value) → adds 'kiwi' at index 1
print(fruits)              # ['apple', 'kiwi', 'blueberry', 'cherry', 'orange']

# --- Removing elements ---

# remove() → removes the FIRST occurrence of the given value does not return anything
fruits.remove("kiwi")

# pop() → removes the LAST element by default and returns it
popped = fruits.pop()
print(popped, fruits)      # orange ['apple', 'blueberry', 'cherry']

# clear() removes all items from a list, making it empty
clear_list = [23,4,54,654]
clear_list.clear()
print(f"The output of clear method: {clear_list}")

# del → deletes the element at the specified index does not return anything
del fruits[0]
print(fruits)              # ['blueberry', 'cherry']

del_list = [23,23,43,54,12,32,89]
del del_list
# print(del_list) Will raise error

# clear() → removes ALL elements from the list; makes it empty []
fruits.clear()
print(fruits)              # []
# Out:
# ['apple', 'blueberry', 'cherry']
# None
# ['apple', 'kiwi', 'blueberry', 'cherry', 'orange', 'orange']
# orange ['apple', 'blueberry', 'cherry', 'orange']
# The output of clear method: []
# ['blueberry', 'cherry', 'orange']
# []

# %%
# Removing duplicates from list: Way - 1
# 1. Using set function:
data = [5,10,10,4,3,5,5,3,6]
print(f"Original List: {data}")
print(list(set(data)))  # [3, 4, 5, 6, 10]
# as above order is not preserved 

# 2. Using loop time complexity O(n2)
data = [5,10,10,4,3,5,5,3,6]
visited_element_list = []
for element in data:
    if element not in visited_element_list:
        visited_element_list.append(element)
print(visited_element_list)

data = [5,10,10,4,3,5,5,3,6]
visited_element_list = []
[visited_element_list.append(element) for element in data if element not in visited_element_list]
print(visited_element_list)


# Using Loops and sets and list time completxity O(n)
data = [5,10,10,4,3,5,5,3,6]

visited = set()
result = []

for element in data:
    if element not in visited:
        visited.add(element)
        result.append(element)

print(result)

# using enemurate : O(n2)
data = [5,10,10,4,3,5,5,3,6]

result = [value for index, value in enumerate(data)
          if value not in data[:index]]

print(result)

# using enemurate + set()  O(n)
data = [5,10,10,4,3,5,5,3,6]

seen = set()
result = []

for index, value in enumerate(data):
    if value not in seen:
        seen.add(value)
        result.append(value)

print(result)

# using dictionary: O(n)
data = [5,10,10,4,3,5,5,3,6]
print(list(dict.fromkeys(data)))
# Out:
# Original List: [5, 10, 10, 4, 3, 5, 5, 3, 6]
# [3, 4, 5, 6, 10]
# [5, 10, 4, 3, 6]
# [5, 10, 4, 3, 6]
# [5, 10, 4, 3, 6]
# [5, 10, 4, 3, 6]
# [5, 10, 4, 3, 6]
# [5, 10, 4, 3, 6]

# %% [markdown]
# ---
# ## 9️⃣ Important List Methods
#
# ### Sorting & Reversing
# | Method | Description |
# |---|---|
# | `list.sort()` | Sorts list **in place** ascending (modifies original) |
# | `list.sort(reverse=True)` | Sorts list **in place** descending |
# | `list.reverse()` | Reverses the list **in place** |
#
# ### Searching & Counting
# | Method | Description |
# |---|---|
# | `list.index(value)` | Returns the **index** of the **first** occurrence of `value`. Raises `ValueError` if not found |
# | `list.index(value, start)` | Searches for `value` starting from `start` index |
# | `list.count(value)` | Returns how many times `value` appears in the list |
#
# ### Copy & Extend
# | Method | Description |
# |---|---|
# | `list.copy()` | Returns a **shallow copy** (new list, same elements) |
# | `list.extend(iterable)` | Adds **all elements** of an iterable/list to the original list **in place** |
#
# > 💡 **`extend()` vs `+` operator**:
# > - `+` creates a **new** list; original lists unchanged
# > - `extend()` **modifies** the original list directly (in-place)

# %%
# ============================================
# 9️⃣ List Methods — Sorting & Reversing
# ============================================

numbers = [5, 3, 8, 1, 9, 5]

# sort() — sorts the list IN PLACE in ascending order (modifies original list)
numbers.sort()
print("Sorted ascending:", numbers)   # [1, 3, 5, 5, 8, 9]

# sort(reverse=True) — sorts the list IN PLACE in descending order
numbers.sort(reverse=True)
print("Sorted descending:", numbers)  # [9, 8, 5, 5, 3, 1]

# reverse() — reverses the current order of elements IN PLACE
numbers.reverse()
print("Reversed:", numbers)           # [1, 3, 5, 5, 8, 9]
# Out:
# Sorted ascending: [1, 3, 5, 5, 8, 9]
# Sorted descending: [9, 8, 5, 5, 3, 1]
# Reversed: [1, 3, 5, 5, 8, 9]

# %%
# ============================================
# 9️⃣ List Methods — count() and index()
# ============================================

numbers = [1, 3, 5, 5, 8, 9]   # list after sorting above

# count(value) — counts how many times 'value' appears in the list
print(numbers.count(5))           # 2   → 5 appears twice (at index 2 and 3)

# index(value) — returns the index of the FIRST occurrence of 'value'
# Raises ValueError if value not found
print(numbers.index(9))           # 5   → 9 is at index 5

# index(value, start) — searches for 'value' starting from 'start' index
# Here we search for 5 starting from index 3 → skips the first 5 at index 2
print(numbers.index(5, 3))        # 3   → finds 5 at index 3 (second occurrence)
# Out:
# 2
# 5
# 3

# %%
# ============================================
# 9️⃣ List Methods — copy() and extend()
# ============================================

numbers = [1, 3, 5, 5, 8, 9]

# copy() — creates a SHALLOW COPY (new list, same element values)
# The new list has a DIFFERENT memory address (id), so they are independent
copy_list = numbers.copy()
print("Copy:", copy_list)           # [1, 3, 5, 5, 8, 9]
print("id of numbers:", id(numbers))    # memory address of original
print("id of copy_list:", id(copy_list))  # DIFFERENT address → separate list

# extend() — adds ALL elements of another list INTO the original list (in-place)
# don't return anything means none
# Unlike +, extend() MODIFIES the original list directly
numbers2 = [10, 20]
numbers.extend(numbers2)
print("After extend:", numbers)     # [1, 3, 5, 5, 8, 9, 10, 20]
sample_tuple = (23,434,"raj",23.7,43)
numbers.extend(sample_tuple)
print(numbers)
# Out:
# Copy: [1, 3, 5, 5, 8, 9]
# id of numbers: 2287588189568
# id of copy_list: 2287588193472
# After extend: [1, 3, 5, 5, 8, 9, 10, 20]
# [1, 3, 5, 5, 8, 9, 10, 20, 23, 434, 'raj', 23.7, 43]

# %% [markdown]
# ---
# ## 🔟 Nested Lists
#
# A list can contain other lists as elements — these are called **nested lists** (or **2D lists**).
#
# They are useful for representing:
# - Matrices / grids
# - Tables of data
# - Multi-dimensional data
#
# **Accessing nested elements:** use double indexing `list[outer_index][inner_index]`
#
# ```python
# nested = [[1, 2], [3, 4], [5, 6]]
# #          ^row0    ^row1    ^row2
# nested[0][1]  →  2   (row 0, column 1)
# nested[2][0]  →  5   (row 2, column 0)
# ```

# %%
# ============================================
# 🔟 Nested Lists
# ============================================

nested = [[1, 2], [3, 4], [5, 6]]

# Accessing nested elements — use TWO indexes: [row][column]
print(nested[0][1])  # 2  → row 0, column 1
print(nested[2][0])  # 5  → row 2, column 0

# Iterating over a nested list — use nested for loops
# Outer loop iterates over each sub-list (row)
# Inner loop iterates over each element inside that sub-list (column)
print("\nAll elements via nested loop:")
for sublist in nested:
    for item in sublist:
        print(item, end=" ")   # 1 2 3 4 5 6
print()  # newline after all elements
# Out:
# 2
# 5
#
# All elements via nested loop:
# 1 2 3 4 5 6

# %% [markdown]
# ---
# ## 1️⃣1️⃣ List Comprehensions
#
# List comprehension is a **concise, one-line** way to create a new list by applying an expression to each element of an iterable — optionally with a condition (filter).
#
# **Syntax:**
# ```python
# [expression  for  item  in  iterable]
# [expression  for  item  in  iterable  if  condition]
# ```
#
# | Pattern | Example |
# |---|---|
# | Simple transformation | `[x**2 for x in range(5)]` |
# | With filter | `[x**2 for x in range(10) if x % 2 == 0]` |
# | Nested comprehension | `[[i*j for j in range(1,4)] for i in range(1,4)]` |
#
# > 💡 List comprehensions are generally **faster** and **more readable** than equivalent `for` loops.

# %%
# ============================================
# 1️⃣1️⃣ List Comprehensions
# ============================================

# --- Basic comprehension ---
# Square of each number from 1 to 5
squares = [x**2 for x in range(1, 6)]
print("Squares:", squares)         # [1, 4, 9, 16, 25]

# --- Comprehension with condition (filter) ---
# Square of only EVEN numbers from 1 to 10
even_squares = [x**2 for x in range(1, 11) if x % 2 == 0]
print("Even squares:", even_squares)  # [4, 16, 36, 64, 100]

# --- Nested list comprehension ---
# Creates a 3x3 multiplication matrix
# Outer loop: i goes 1, 2, 3 (rows)
# Inner loop: j goes 1, 2, 3 (columns) → each cell = i * j
matrix = [[i * j for j in range(1, 4)] for i in range(1, 4)]
print("Matrix:", matrix)           # [[1,2,3], [2,4,6], [3,6,9]]
# Out:
# Squares: [1, 4, 9, 16, 25]
# Even squares: [4, 16, 36, 64, 100]
# Matrix: [[1, 2, 3], [2, 4, 6], [3, 6, 9]]

# %%
"""
Python List Comprehension – Complete Guide
------------------------------------------

List comprehension is a concise way to create lists in Python.

Instead of writing multiple lines using loops,
we can write it in a single readable line.

--------------------------------------------------
SYNTAX TYPES
--------------------------------------------------

Syntax-01 : Normal
[expression for variable in iterable]

Syntax-02 : If condition
[expression for variable in iterable if condition]

Syntax-03 : Nested if
[expression for variable in iterable if cond1 if cond2]

Syntax-04 : If-else
[expression_if_true if condition else expression_if_false for variable in iterable]
"""

# ==================================================
# 1. BASIC LIST COMPREHENSION
# ==================================================

print("1️⃣ BASIC LIST COMPREHENSION")

# Syntax
# [expression for variable in iterable]

numbers = [1, 2, 3, 4, 5]

# Normal for loop
squares_loop = []
for num in numbers:
    squares_loop.append(num ** 2)

print("Using normal loop:", squares_loop)

# List comprehension
squares_lc = [num ** 2 for num in numbers]

print("Using list comprehension:", squares_lc)


# ==================================================
# 2. LIST COMPREHENSION WITH IF CONDITION
# ==================================================

print("\n2️⃣ LIST COMPREHENSION WITH IF CONDITION")

# Syntax
# [expression for variable in iterable if condition]

numbers = [1, 2, 3, 4, 5, 6]

# Square only even numbers
even_squares = [num ** 2 for num in numbers if num % 2 == 0]

print("Squares of even numbers:", even_squares)


# ==================================================
# 3. LIST COMPREHENSION WITH NESTED IF CONDITIONS
# ==================================================

print("\n3️⃣ LIST COMPREHENSION WITH NESTED IF")

# Syntax
# [expression for variable in iterable if cond1 if cond2]

numbers = [1, 2, 3, 4, 5, 6, 7, 8]

# Square numbers that are even AND greater than 4
result_nested_if = [num ** 2 for num in numbers if num % 2 == 0 if num > 4]

print("Even numbers greater than 4 squared:", result_nested_if)


# ==================================================
# 4. LIST COMPREHENSION WITH IF-ELSE
# ==================================================

print("\n4️⃣ LIST COMPREHENSION WITH IF-ELSE")

# Syntax
# [expression_if_true if condition else expression_if_false for variable in iterable]

numbers = [1, 2, 3, 4, 5]

# If even -> square it
# If odd -> keep number same
result_if_else = [num ** 2 if num % 2 == 0 else num for num in numbers]

print("If even square else keep same:", result_if_else)


# ==================================================
# 5. NESTED LIST COMPREHENSION (Nested loops)
# ==================================================

print("\n5️⃣ NESTED LIST COMPREHENSION")

matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# Syntax
# [expression for row in matrix for element in row]

flatten_matrix = [element for row in matrix for element in row]

print("Flattened matrix:", flatten_matrix)


# Equivalent normal loop
flatten_loop = []

for row in matrix:
    for element in row:
        flatten_loop.append(element)

print("Flatten using normal loop:", flatten_loop)


# ==================================================
# MAIN TAKEAWAY
# ==================================================

"""
Key Takeaways
-------------

1. List comprehension makes code shorter and cleaner.
2. Often faster than traditional loops.
3. Supports filtering using 'if'.
4. Supports conditional expressions using 'if-else'.
5. Can represent nested loops.

But remember:
If logic becomes too complex, using normal loops
is better for readability.

"""
# Out:
# 1️⃣ BASIC LIST COMPREHENSION
# Using normal loop: [1, 4, 9, 16, 25]
# Using list comprehension: [1, 4, 9, 16, 25]
#
# 2️⃣ LIST COMPREHENSION WITH IF CONDITION
# Squares of even numbers: [4, 16, 36]
#
# 3️⃣ LIST COMPREHENSION WITH NESTED IF
# Even numbers greater than 4 squared: [36, 64]
#
# 4️⃣ LIST COMPREHENSION WITH IF-ELSE
# If even square else keep same: [1, 4, 3, 16, 5]
#
# 5️⃣ NESTED LIST COMPREHENSION
# Flattened matrix: [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Flatten using normal loop: [1, 2, 3, 4, 5, 6, 7, 8, 9]
# "\nKey Takeaways\n-------------\n\n1. List comprehension makes code shorter and cleaner.\n2. Often faster than traditional loops.\n3. Supports filtering using 'if'.\n4. Supports conditional expressions using 'if-else'.\n5. Can represent nested loops.\n\nBut remember:\nIf logic becomes too complex, using normal loops\nis better for readability.\n\n"

# %% [markdown]
# ---
# ## 1️⃣2️⃣ Converting Other Iterables to List
#
# The `list()` constructor can convert any **iterable** (string, tuple, set, range, etc.) into a list.
#
# | Iterable | Example | Result |
# |---|---|---|
# | String | `list("hello")` | `['h', 'e', 'l', 'l', 'o']` |
# | Tuple | `list((1, 2, 3))` | `[1, 2, 3]` |
# | Range | `list(range(5))` | `[0, 1, 2, 3, 4]` |
# | Set | `list({1, 2, 3})` | `[1, 2, 3]` (order may vary) |
#
# > 💡 When you convert a **string** to a list, each **character** becomes a separate element.

# %%
# ============================================
# 1️⃣2️⃣ Converting Other Iterables to List
# ============================================

# Converting a STRING to a list
# Each character of the string becomes a separate element
s = "hello"
print(list(s))     # ['h', 'e', 'l', 'l', 'o']

# Converting a TUPLE to a list
t = (1, 2, 3)
print(list(t))     # [1, 2, 3]
# Out:
# ['h', 'e', 'l', 'l', 'o']
# [1, 2, 3]

# %% [markdown]
# ---
# ## 1️⃣3️⃣ Copying Lists — Shallow Copy vs Deep Copy
#
# When you copy a list, there are two types:
#
# ### 1️⃣ Shallow Copy (`list.copy()` or `copy.copy()`)
# - Creates a **new top-level list**.
# - But **nested inner lists** still point to the **same objects** in memory as the original.
# - ✅ Changes to the top-level list (add/remove elements) **do NOT affect** the original.
# - ❌ Changes to **inner (nested) lists** **WILL affect** the original (because they share references).
#
# ### 2️⃣ Deep Copy (`copy.deepcopy()`)
# - Creates a **100% independent copy** of everything, including all nested objects.
# - ✅ Changes at **any level** of the copied list **do NOT affect** the original.
# - Use `import copy` to access `deepcopy()`.
#
# ```
# Shallow Copy:
#   original → [ [1,2], [3,4] ]
#                 ↑        ↑
#   copy     → [ [1,2], [3,4] ]   ← inner lists SHARED!
#
# Deep Copy:
#   original → [ [1,2], [3,4] ]
#   copy     → [ [1,2], [3,4] ]   ← completely independent!
# ```
#
# > 💡 **Rule of thumb**: Use `.copy()` for flat (non-nested) lists. Use `deepcopy()` for nested lists.

# %%
# ============================================
# 1️⃣3️⃣ Shallow Copy — list.copy()
# ============================================

# Simple (flat) list — shallow copy works perfectly
a = [1, 2, 3]
b = a.copy()   # b is a new list with same values
b[0] = 100     # modifying b's top-level element

print(a, b)    # [1, 2, 3] [100, 2, 3] → a is NOT affected ✅

# ---- Limitation of Shallow Copy with NESTED lists ----

nested1 = [[1, 2], [3, 4]]

# Shallow copy — creates a new outer list, but inner lists are still SHARED
anotherCopy = nested1.copy()

# Modifying the TOP-LEVEL list of the copy (appending a new sub-list)
anotherCopy.append([5, 6])
print("nested1:", nested1)         # [[1,2],[3,4]]        → unchanged ✅
print("anotherCopy:", anotherCopy) # [[1,2],[3,4],[5,6]]  → copy changed

# Modifying an INNER list element of the copy
# ❌ This ALSO changes nested1 because both share the same inner list objects!
anotherCopy[0][0] = 100
print("nested1 after inner change:", nested1)      # [[100,2],[3,4]] → AFFECTED! ❌
print("anotherCopy after inner change:", anotherCopy)  # [[100,2],[3,4],[5,6]]
# Out:
# [1, 2, 3] [100, 2, 3]
# nested1: [[1, 2], [3, 4]]
# anotherCopy: [[1, 2], [3, 4], [5, 6]]
# nested1 after inner change: [[100, 2], [3, 4]]
# anotherCopy after inner change: [[100, 2], [3, 4], [5, 6]]

# %%
# ============================================
# 1️⃣3️⃣ Deep Copy — copy.deepcopy()
# ============================================

import copy  # Must import the copy module to use deepcopy

nested1 = [[1, 2], [3, 4]]

# deepcopy() creates a COMPLETELY INDEPENDENT copy at ALL levels
# No shared references — original and copy are fully separate
nested2 = copy.deepcopy(nested1)

# Modifying an inner element of the deep copy
nested2[0][0] = 100

print("nested1:", nested1)   # [[1,2],[3,4]]   → original UNCHANGED ✅
print("nested2:", nested2)   # [[100,2],[3,4]] → only copy changed ✅
# Out:
# nested1: [[1, 2], [3, 4]]
# nested2: [[100, 2], [3, 4]]

# %% [markdown]
# ---
# ## ✅ Quick Summary — Python Lists
#
# | Concept | Key Point |
# |---|---|
# | **Definition** | Mutable, ordered, indexed, allows duplicates |
# | **Heterogeneous** | Can store mixed types: `int`, `str`, `bool`, lists, etc. |
# | **Indexing** | Positive (`0` to `n-1`) and Negative (`-1` to `-n`) |
# | **Slicing** | `list[start:stop:step]` — extracts sub-list |
# | **Iteration** | `for`, `enumerate()`, `while` |
# | **Operations** | `+` (concat), `*` (repeat), `in`/`not in` (membership), `len()` |
# | **Aggregates** | `min()`, `max()`, `sum()` |
# | **Modification** | `append`, `insert`, `remove`, `pop`, `del`, `clear` |
# | **Methods** | `sort`, `reverse`, `count`, `index`, `copy`, `extend` |
# | **Nested Lists** | Lists inside lists; access with `list[i][j]` |
# | **Comprehension** | `[expr for x in iterable if condition]` |
# | **Conversion** | `list()` converts any iterable to a list |
# | **Shallow Copy** | `.copy()` — shares inner objects (nested lists affected) |
# | **Deep Copy** | `copy.deepcopy()` — fully independent at all levels |
