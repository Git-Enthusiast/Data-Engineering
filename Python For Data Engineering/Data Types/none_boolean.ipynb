# %% [markdown]
# # 🧩 Python NoneType & Boolean Data Types
#
# This notebook explains two fundamental data types in Python:
#
# 1. **NoneType**
# 2. **Boolean (`bool`)**
#
# Both are very important for **control flow, conditions, and logic building**.

# %% [markdown]
# ---
# # 1️⃣ NoneType
#
# ## 📌 What is None?
# - `None` represents the **absence of a value**.
# - Similar to `NULL` in C/C++/Java.
# - It means: **"No value assigned yet"**.
#
# ## 📌 Why use None?
# - To declare a variable **before** assigning an actual value.
# - Prevents syntax errors.
# - Useful when value will be assigned later.
#
# ```python
# result = None
# # Later in code
# result = 10
# ```
#
# ## 📌 Important Points
# - `None` is a **keyword**.
# - There is only **ONE** `None` object in Python (**singleton**).
# - `None` is **immutable**.
# - `None` is considered **False** in boolean context.
# - Type of `None` is `<class 'NoneType'>`.

# %%
# NoneType Examples
print("NoneType Examples:")
x = None
print("Value of x:", x)
print("Type of x:", type(x))

# Checking if variable is None
if x is None:
    print("x is None")
# Out:
# NoneType Examples:
# Value of x: None
# Type of x: <class 'NoneType'>
# x is None

# %% [markdown]
# ---
# # 2️⃣ Boolean Data Type
#
# ## 📌 What is Boolean?
# - Boolean data type represents **logical values**.
# - It has only **TWO values:** `True` and `False`.
# - Type: `<class 'bool'>`
#
# ## 📌 Important Notes
# - `True` and `False` are **keywords**.
# - Boolean is a **subclass of `int`**.
#     - `True` → `1`
#     - `False` → `0`
#
# ```python
# True + True  = 2
# True + False = 1
# ```

# %%
# Boolean Examples
print("Boolean Examples:")
a = True
b = False

print("Value of a:", a, type(a))
print("Value of b:", b, type(b))

# Boolean as integers
print("\nBoolean as integers:")
print("True + True =", True + True)
print("True + False =", True + False)
print("False + False =", False + False)
# Out:
# Boolean Examples:
# Value of a: True <class 'bool'>
# Value of b: False <class 'bool'>
#
# Boolean as integers:
# True + True = 2
# True + False = 1
# False + False = 0

# %% [markdown]
# ---
# ## 📌 Truthiness & Falsiness in Python
#
# Python evaluates values as `True` or `False` automatically when used inside conditions.
#
# ### Values considered **FALSE** (Falsy):
#
# | Value | Type |
# |-------|------|
# | `0` | int |
# | `0.0` | float |
# | `False` | bool |
# | `None` | NoneType |
# | `[]` | Empty list |
# | `()` | Empty tuple |
# | `{}` | Empty dict |
# | `set()` | Empty set |
# | `""` | Empty string |
#
# ### Values considered **TRUE** (Truthy):
#
# | Value | Type |
# |-------|------|
# | `5`, `-3`, `2.5` | Non-zero numbers |
# | `[1]` | Non-empty list |
# | `{"a":1}` | Non-empty dict |
# | `{1}` | Non-empty set |
# | `(1,)` | Non-empty tuple |
# | `"Hello"` | Non-empty string |
# | `True` | bool |

# %%
# Truthiness & Falsiness Examples
print("Truthiness & Falsiness:")

# Zero → False
if 0:
    print("0 is True")
else:
    print("0 is False")

# Non-zero → True
if 5:
    print("5 is True")

# None → False
if None:
    print("None is True")
else:
    print("None is False")

# Empty list → False
if []:
    print("Empty list is True")
else:
    print("Empty list is False")

# Non-empty list → True
if [1, 2, 3]:
    print("Non-empty list is True")

# Empty string → False
if "":
    print("Empty string is True")
else:
    print("Empty string is False")

# Non-empty string → True
if "Python":
    print("Non-empty string is True")
# Out:
# Truthiness & Falsiness:
# 0 is False
# 5 is True
# None is False
# Empty list is False
# Non-empty list is True
# Empty string is False
# Non-empty string is True

# %%
# Boolean Expressions
print("Boolean Expressions:")

print("10 > 5:", 10 > 5)
print("5 == 5:", 5 == 5)
print("3 < 1:", 3 < 1)

# Using bool() function
print("\nUsing bool() function:")
print("bool(0):", bool(0))
print("bool(10):", bool(10))
print("bool(None):", bool(None))
print("bool([]):", bool([]))
print("bool([1]):", bool([1]))
# Out:
# Boolean Expressions:
# 10 > 5: True
# 5 == 5: True
# 3 < 1: False
#
# Using bool() function:
# bool(0): False
# bool(10): True
# bool(None): False
# bool([]): False
# bool([1]): True

# %% [markdown]
# ---
# # 🧠 Deep Dive: `bool` as Subclass of `int`
#
# This is a very common interview question.
#
# ## 1️⃣ Proof – Is `bool` really a subclass of `int`?
#
# ```python
# print(issubclass(bool, int))   # True
# print(isinstance(True, int))   # True
# print(isinstance(False, int))  # True
# ```
#
# So officially: **`bool` → subclass of `int`**
#
# ## 2️⃣ Why Did Python Design It This Way?
#
# In Python: `True = 1`, `False = 0` — not just conceptually, but **internally** also.
#
# This design allows:
# - Arithmetic with boolean values
# - Logical operations combined with numeric calculations
# - Clean counting patterns
#
# ## 3️⃣ Internal Hierarchy
#
# ```
# object
#    ↓
#   int
#    ↓
#  bool
# ```
#
# **MRO (Method Resolution Order):**
# ```python
# print(bool.__mro__)
# # (<class 'bool'>, <class 'int'>, <class 'object'>)
# ```

# %%
# Proof: bool is subclass of int
print("issubclass(bool, int):", issubclass(bool, int))
print("isinstance(True, int):", isinstance(True, int))
print("isinstance(False, int):", isinstance(False, int))

print("\nint(True):", int(True))
print("int(False):", int(False))

print("\nMRO:", bool.__mro__)
# Out:
# issubclass(bool, int): True
# isinstance(True, int): True
# isinstance(False, int): True
#
# int(True): 1
# int(False): 0
#
# MRO: (<class 'bool'>, <class 'int'>, <class 'object'>)

# %%
# Arithmetic Behavior of bool (since subclass of int)
print("Arithmetic with booleans:")
print("True + True =", True + True)       # 2
print("True + False =", True + False)     # 1
print("False + False =", False + False)   # 0
print("True * 10 =", True * 10)           # 10
print("False * 10 =", False * 10)         # 0
# Out:
# Arithmetic with booleans:
# True + True = 2
# True + False = 1
# False + False = 0
# True * 10 = 10
# False * 10 = 0

# %% [markdown]
# ## 4️⃣ Memory-Level Behavior
#
# Although `True == 1`, they are **not the same object**:
#
# ```python
# True == 1   → True  (value equality)
# True is 1   → False (identity difference)
# ```
#
# > 🔥 **Interview Key Point:** `==` checks **value**, `is` checks **identity (memory address)**.

# %%
# == vs is with True and 1
print("True == 1:", True == 1)     # True  (value equality)
print("True is 1:", True is 1)     # False (identity difference)
print("False == 0:", False == 0)   # True
print("False is 0:", False is 0)   # False

print("\ntype(True):", type(True))   # <class 'bool'>
print("type(1):", type(1))           # <class 'int'>
# Out:
# True == 1: True
# True is 1: False
# False == 0: True
# False is 0: False
#
# type(True): <class 'bool'>
# type(1): <class 'int'>
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\niraj\AppData\Local\Temp\ipykernel_17332\4242868879.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print("True is 1:", True is 1)     # False (identity difference)
# C:\Users\niraj\AppData\Local\Temp\ipykernel_17332\4242868879.py:5: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print("False is 0:", False is 0)   # False

# %% [markdown]
# ## 5️⃣ Practical Real-World Usage
#
# Since `True = 1` and `False = 0`, you get elegant counting patterns:
#
# ```python
# numbers = [10, 15, 20, 25, 30]
# count = sum(n > 18 for n in numbers)  # count how many > 18
# # (n > 18) → True or False → 1 or 0 → sum() adds them
# ```
#
# 🔥 This is elegant Python design.

# %%
# Counting with boolean + sum pattern
numbers = [10, 15, 20, 25, 30]
count = sum(n > 18 for n in numbers)
print(f"Numbers > 18: {count}")   # 3
# Out:
# Numbers > 18: 3

# %% [markdown]
# ## 6️⃣ Boolean in Bitwise Operations
#
# Since `bool` is `int`, bitwise operators work on booleans like `1` and `0`.

# %%
# Bitwise operations on booleans
print("True & False:", True & False)   # False (1 & 0 = 0)
print("True | False:", True | False)   # True  (1 | 0 = 1)
print("True ^ False:", True ^ False)   # True  (1 ^ 0 = 1)
# Out:
# True & False: False
# True | False: True
# True ^ False: True

# %% [markdown]
# ## 7️⃣ Interview Edge Cases
#
# ```python
# True + True * False
# # Step 1: True * False → 1 * 0 → 0
# # Step 2: True + 0 → 1
# # Output: 1
# ```
#
# ### ⚠️ When NOT to Treat `bool` as `int`
#
# Avoid: `x = True + 5` (reduces readability)
# Better: `x = int(True) + 5` (cleaner intention)
#
# ### 🎯 If Interviewer Asks:
# > **Q: Why is `bool` subclass of `int` in Python?**
# >
# > **Best Answer:** Python treats boolean values as special integers for mathematical consistency and simplicity. `True` behaves like `1` and `False` behaves like `0`, allowing boolean expressions to participate naturally in arithmetic operations while still maintaining logical semantics.

# %%
# Interview edge case
print("True + True * False =", True + True * False)  # 1

# bool is immutable (like int)
print("\nbool(2):", bool(2))     # True
print("bool(0):", bool(0))       # False
print("True.__class__:", True.__class__)  # <class 'bool'>
# Out:
# True + True * False = 1
#
# bool(2): True
# bool(0): False
# True.__class__: <class 'bool'>

# %% [markdown]
# ---
# # 🧠 Deep Dive: None Internals
#
# ## 1️⃣ What Exactly is None?
# - A special **constant** in Python
# - Represents **absence of value**
# - **Only instance** of `NoneType`
# - A **singleton** object
#
# ## 2️⃣ NoneType Hierarchy
#
# ```
# object
#    ↓
# NoneType
# ```
#
# ```python
# print(type(None).__mro__)
# # (<class 'NoneType'>, <class 'object'>)
# ```
#
# > 👉 You **cannot** create another `NoneType` object manually. `NoneType()` → ❌ Not allowed.

# %%
# None internals
print("type(None):", type(None))             # <class 'NoneType'>
print("None.__class__:", None.__class__)      # <class 'NoneType'>
print("MRO:", type(None).__mro__)              # (<class 'NoneType'>, <class 'object'>)
# Out:
# type(None): <class 'NoneType'>
# None.__class__: <class 'NoneType'>
# MRO: (<class 'NoneType'>, <class 'object'>)

# %% [markdown]
# ## 3️⃣ Singleton Pattern – There Is Only ONE `None`
#
# Python creates only **one** `None` object in memory. This is called the **Singleton Design Pattern**.
#
# Internally (CPython): `Py_None` — a globally shared object.

# %%
# Singleton proof
a = None
b = None

print("a is b:", a is b)       # True (same object in memory)
print("id(a):", id(a))
print("id(b):", id(b))         # Same ID
print("id(None):", id(None))   # Always same ID
# Out:
# a is b: True
# id(a): 140725076077376
# id(b): 140725076077376
# id(None): 140725076077376

# %% [markdown]
# ## 4️⃣ Why Use `is` Instead of `==` With None?
#
# **Best practice:**
# ```python
# if x is None:      # ✅ Correct
# if x == None:      # ❌ Avoid
# ```
#
# **Why?**
# - `is` checks **identity** (memory) — `None` is singleton, so identity check is correct.
# - `==` can be **overridden** by objects, leading to dangerous false positives.
#
# 🔥 **Interview gold point.**

# %%
# Dangerous example: == can be overridden
class Test:
    def __eq__(self, other):
        return True  # Always returns True for ==

t = Test()
print("t == None:", t == None)   # True (dangerous!)
print("t is None:", t is None)   # False (correct check)
# Out:
# t == None: True
# t is None: False

# %% [markdown]
# ## 5️⃣ None in Functions (Very Important)
#
# If a function **does not return anything**, Python automatically returns `None` (**implicit return**).

# %%
# Implicit return of None
def greet():
    print("Hello")

x = greet()
print("Return value:", x)        # None
print("Type:", type(x))          # <class 'NoneType'>
# Out:
# Hello
# Return value: None
# Type: <class 'NoneType'>

# %% [markdown]
# ## 6️⃣ None vs `0` vs Empty String vs `False`
#
# Even though all are **falsy**, they are **NOT equal**:
#
# ```
# Falsy ≠ Equal
# ```

# %%
# None is NOT equal to other falsy values
print("None == 0:", None == 0)         # False
print("None == '':", None == "")       # False
print("None == False:", None == False) # False

# But all are falsy
print("\nbool(None):", bool(None))     # False
print("bool(0):", bool(0))             # False
print("bool(''):", bool(""))           # False
print("bool(False):", bool(False))     # False
# Out:
# None == 0: False
# None == '': False
# None == False: False
#
# bool(None): False
# bool(0): False
# bool(''): False
# bool(False): False

# %% [markdown]
# ## 7️⃣ Common Interview Trap: `if not x` vs `if x is None`
#
# | Check | Meaning |
# |-------|---------|
# | `if not x` | General **falsy** check (catches `0`, `[]`, `""`, `None`, etc.) |
# | `if x is None` | **Exact** None check (only catches `None`) |
#
# > Use `is None` when you specifically want to check for **absence of value**, not just any falsy value.

# %%
# Difference between 'if not x' and 'if x is None'
x = []
if not x:
    print("'if not x' triggers for empty list")   # Triggers!
if x is None:
    print("'if x is None' triggers for empty list")
else:
    print("'if x is None' does NOT trigger for empty list")  # This runs
# Out:
# 'if not x' triggers for empty list
# 'if x is None' does NOT trigger for empty list

# %% [markdown]
# ## 8️⃣ Can You Reassign `None`?
#
# **No.** `None` is a **keyword** and a **reserved constant**.
#
# ```python
# None = 5   # ❌ SyntaxError
# ```
#
# ## 9️⃣ Internal CPython Implementation
#
# In CPython source:
# ```c
# PyObject _Py_NoneStruct = {
#     PyObject_HEAD_INIT(&_PyNone_Type)
# };
# ```
# Exposed as `Py_None`:
# - Created **once**
# - Lives for **entire interpreter lifetime**
# - Reference counted but **never destroyed**
# - Never garbage collected (global static object)
#
# ## 🔟 Why Python Uses `None` Instead of NULL Pointer?
#
# | Feature | C/C++ `NULL` | Python `None` |
# |---------|-------------|---------------|
# | What is it? | Memory address 0 | Safe object |
# | Dereferencing | 💥 Crash | ✅ Normal object behavior |
# | Safety | Dangerous | Safer design |
#
# ### 🎯 If Interviewer Asks:
# > **Q: Why is `None` implemented as singleton in Python?**
# >
# > **Best Answer:** `None` represents the absence of value and must be universally consistent across the interpreter. Making it a singleton ensures memory efficiency, identity reliability, and consistent behavior when checking with `is`.

# %% [markdown]
# ---
# # 🎯 Final Summary
#
# ## 🔹 NoneType
# - ✔ Represents **absence of value**
# - ✔ Similar to NULL
# - ✔ Only one `None` object (**singleton**)
# - ✔ Immutable
# - ✔ Evaluates to `False`
# - ✔ Always use `is None` (not `== None`)
# - ✔ Implicit return value of functions
# - ✔ Falsy but **not equal** to `False`
# - ✔ Cannot instantiate `NoneType` manually
# - ✔ Exists for entire interpreter lifetime
#
# ## 🔹 Boolean (`bool`)
# - ✔ Two values: `True` and `False`
# - ✔ **Subclass of `int`**
# - ✔ `True = 1`, `False = 0`
# - ✔ Supports arithmetic & bitwise operations
# - ✔ `True == 1` but `True is 1` is `False`
# - ✔ Check hierarchy with `bool.__mro__`
# - ✔ Enables elegant counting patterns (`sum()`)
#
# ## 🔹 Truthy vs Falsy
# - ✔ **Truthy:** Non-zero numbers, non-empty collections, `True`
# - ✔ **Falsy:** `0`, `0.0`, `None`, `False`, empty collections, empty string
#
# ```
# END OF MASTER FILE
# ```
