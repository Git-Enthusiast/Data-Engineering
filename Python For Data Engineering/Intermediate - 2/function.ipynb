# %%
def greeting():
    print("Hello")
    return "Python"

print(type(greeting)) # class 'function' 
print(display)  # function display at 0x000002776A0DDB10
# so now above it gives address where function is stored 
# as we know that in python object is stored and has memory 
# address here function so also an object
# Out:
# <class 'function'>
# <function display at 0x0000020B125914E0>

# %%
# Creating alisas for the function
def display ():
    print("Hello Word!")

var = display   # so now here var can be also used instead of display
another_var = display
another_var()
var()
display()
# Out:
# Hello Word!
# Hello Word!
# Hello Word!

# %%
# Nested function
# nested_function_example.py
# Example to demonstrate Nested Functions in Python

def outer_function(name):
    print("Outer function started")

    # Nested function (function inside another function)
    def inner_function():
        print("Hello", name)
        print("This is the inner function")

    # Calling the inner function
    inner_function()

    print("Outer function ended")


# Calling the outer function
outer_function("Rajan")
# Out:
# Outer function started
# Hello Rajan
# This is the inner function
# Outer function ended

# %%
# positional and keyword arguements 

# Function definition
def student_details(name, age, course):
    print("Name:", name)
    print("Age:", age)
    print("Course:", course)
    print("-------------------")


print("Using Positional Arguments")
# Positional Arguments (order matters)
student_details("Rajan", 22, "Computer Science")


print("Using Keyword Arguments")
# Keyword Arguments (order does not matter)
student_details(course="Computer Science", name="Rajan", age=22)
# Out:
# Using Positional Arguments
# Name: Rajan
# Age: 22
# Course: Computer Science
# -------------------
# Using Keyword Arguments
# Name: Rajan
# Age: 22
# Course: Computer Science
# -------------------

# %%
# default_arguments_example.py
# Example of Default Arguments in Python

def greet(name, message="Welcome"): # Default arguments always at the last else error
    print(message, name)

# Calling function with both arguments
greet("Rajan", "Good Morning")

# Calling function with only one argument
# Default value of message will be used
greet("Rajan")
# Out:
# Good Morning Rajan
# Welcome Rajan

# %%
# variable_arguments_example.py
# Example of *args and **kwargs

# Example of *args
def add_numbers(*numbers):
    total = 0
    for num in numbers:
        total += num
    print("Sum =", total)

# Calling function with different number of arguments
add_numbers(10, 20)
add_numbers(5, 10, 15, 20)


print("----------------------")

# Example of **kwargs
def student_info(**details):
    for key, value in details.items():
        print(key, ":", value)

# Calling function with keyword arguments
student_info(name="Rajan", age=22, course="CSE")
# Out:
# Sum = 30
# Sum = 50
# ----------------------
# name : Rajan
# age : 22
# course : CSE

# %%
# Mutable default arguements
# In Python for mutable default arguments if it is a mutable object
# it is created once and reused again and again after calling. 
# Example to demonstrate Mutable Default Arguments in Python

# Function with a mutable default argument (list)
def add_item(item, item_list=[]):   # Default arguments always at the last else error
    item_list.append(item)
    return item_list

# Calling the function multiple times
print(add_item("Apple"))
print(add_item("Banana"))
print(add_item("Mango"))

'''

🔹 Explanation
The default argument item_list=[] is a mutable object (list).
In Python, default arguments are created only once when the function is defined.
So the same list is shared across multiple function calls.

That is why:

First call → ['Apple']
Second call → ['Apple', 'Banana']
Third call → ['Apple', 'Banana', 'Mango']

The list keeps growing instead of resetting.

''' 

#✅ Correct Way to Handle Mutable Default Arguments
#📄 Example: mutable_default_correct.py
# Correct way to avoid mutable default argument problem

def add_item(item, item_list=None):
    if item_list is None:
        item_list = []

    item_list.append(item)
    return item_list

print(add_item("Apple"))
print(add_item("Banana"))
print(add_item("Mango"))


''' 
📌 Key Points
Mutable objects: list, dictionary, set.
Default mutable arguments can cause unexpected behavior.
Best practice is to use None as default value and create a new object inside the function.
'''
# Out:
# ['Apple']
# ['Apple', 'Banana']
# ['Apple', 'Banana', 'Mango']
# ['Apple']
# ['Banana']
# ['Mango']
# ' \n📌 Key Points\nMutable objects: list, dictionary, set.\nDefault mutable arguments can cause unexpected behavior.\nBest practice is to use None as default value and create a new object inside the function.\n'

# %%
# python_functions_demo.py
# Demonstration of different types of functions and arguments in Python

print("----- 1. Nested Function Example -----")

def outer_function(name):
    def inner_function():
        print("Hello", name)
    inner_function()

outer_function("Rajan")


print("\n----- 2. Positional Arguments -----")

def student_info(name, age, course):
    print("Name:", name)
    print("Age:", age)
    print("Course:", course)

student_info("Rajan", 22, "Computer Science")


print("\n----- 3. Keyword Arguments -----")

student_info(age=22, course="Computer Science", name="Rajan")


print("\n----- 4. Default Arguments -----")

def greet(name, message="Welcome"): # Here order matters so default arguments 
                                    # always comes at the end
    print(message, name)

greet("Rajan")
greet("Rajan", "Good Morning")


print("\n----- 5. Variable Length Arguments (*args) -----")

def add_numbers(*numbers):
    total = 0
    for num in numbers:
        total += num
    print("Sum =", total)

add_numbers(10, 20)
add_numbers(5, 10, 15, 20)


print("\n----- 6. Variable Length Keyword Arguments (**kwargs) -----")

def display_details(**details):
    for key, value in details.items():
        print(key, ":", value)

display_details(name="Rajan", age=22, course="CSE")


print("\n----- 7. Mutable Default Argument Problem -----")

def add_item(item, item_list=[]):
    item_list.append(item)
    return item_list

print(add_item("Apple"))
print(add_item("Banana"))


print("\n----- 8. Correct Way to Handle Mutable Default Argument -----")

def add_item_safe(item, item_list=None):
    if item_list is None:
        item_list = []
    item_list.append(item)
    return item_list

print(add_item_safe("Apple"))
print(add_item_safe("Banana"))
# Out:
# ----- 1. Nested Function Example -----
# Hello Rajan
#
# ----- 2. Positional Arguments -----
# Name: Rajan
# Age: 22
# Course: Computer Science
#
# ----- 3. Keyword Arguments -----
# Name: Rajan
# Age: 22
# Course: Computer Science
#
# ----- 4. Default Arguments -----
# Welcome Rajan
# Good Morning Rajan
#
# ----- 5. Variable Length Arguments (*args) -----
# Sum = 30
# Sum = 50
#
# ----- 6. Variable Length Keyword Arguments (**kwargs) -----
# name : Rajan
# age : 22
# course : CSE
#
# ----- 7. Mutable Default Argument Problem -----
# ['Apple']
# ['Apple', 'Banana']
#
# ----- 8. Correct Way to Handle Mutable Default Argument -----
# ['Apple']
# ['Banana']

# %%
# Mixing variable length positional and keyword arguments 
# so order should be first positional and keyword arguments
def my_fun(*num, **nums):
    print(num)
    print(nums)
my_fun(12,23,"rajan", n1 = 3, n2 = 23, n3 = 2323)
# Out:
# (12, 23, 'rajan')
# {'n1': 3, 'n2': 23, 'n3': 2323}

# %%
# Mixing positional and keyword arugments 
def details(name, age):
    print(name)
    print(age)
details("Rajan", age = 23)
# So always pass positional arguments first then keyword arguments else get error
# Out:
# Rajan
# 23

# %%
# Default arguments should be always at the end 
#def details(name = "N/A", age): 
#SyntaxError: parameter without a default follows parameter with a default
def details(age, name = "N/A"):
    print(name)
    print(age)
details(age = 23)
# always Default at the end
# Out:
# N/A
# 23

# %%
# Demonstration of all types of arguments in Python

"""
Types of Function Arguments in Python
1. Positional Arguments
2. Keyword Arguments
3. Default Arguments
4. Variable Length Positional Arguments (*args)
5. Variable Length Keyword Arguments (**kwargs)

Correct Order While Defining Function:

1. Positional arguments
2. Default arguments
3. *args (variable length positional arguments)
4. **kwargs (variable length keyword arguments)
"""

def student_info(name, course="B.Tech", *skills, **details):
    """
    name      -> Positional Argument
    course    -> Default Argument
    *skills   -> Variable Length Positional Arguments
    **details -> Variable Length Keyword Arguments
    """

    print("----- Student Information -----")

    # Positional argument
    print("Name:", name)

    # Default argument
    print("Course:", course)

    # Variable length positional arguments
    print("\nSkills (*args):")
    if skills:
        for skill in skills:
            print("-", skill)
    else:
        print("No skills provided")

    # Variable length keyword arguments
    print("\nAdditional Details (**kwargs):")
    if details:
        for key, value in details.items():
            print(f"{key}: {value}")
    else:
        print("No extra details provided")


# Function Call Demonstration

print("\nExample 1: Positional Arguments")
student_info("Rajan")

print("\nExample 2: Keyword Argument")
student_info(name="Ravi", course="BCA")

print("\nExample 3: Using *args")
student_info("Ankit", "B.Sc", "Python", "Java", "SQL")

print("\nExample 4: Using **kwargs")
student_info("Priya", "BBA", city="Delhi", age=20)

print("\nExample 5: Mixing All Types")
student_info(
    "Aman",
    "MCA",
    "C",
    "C++",
    "Python",
    city="Patna",
    age=21,
    hobby="Music"
)
'''
orrect Order Rule in Python

The valid order for parameters is:

1. Positional arguments
2. Default arguments
3. *args
4. Keyword-only arguments
5. **kwargs

And **kwargs must always be last.

'''
# Out:
# Example 1: Positional Arguments
# ----- Student Information -----
# Name: Rajan
# Course: B.Tech
#
# Skills (*args):
# No skills provided
#
# Additional Details (**kwargs):
# No extra details provided
#
# Example 2: Keyword Argument
# ----- Student Information -----
# Name: Ravi
# Course: BCA
#
# Skills (*args):
# No skills provided
#
# Additional Details (**kwargs):
# No extra details provided
#
# Example 3: Using *args
# ----- Student Information -----
# Name: Ankit
# Course: B.Sc
#
# Skills (*args):
# - Python
# - Java
# - SQL
#
# Additional Details (**kwargs):
# No extra details provided
#
# Example 4: Using **kwargs
# ----- Student Information -----
# Name: Priya
# Course: BBA
#
# Skills (*args):
# No skills provided
#
# Additional Details (**kwargs):
# city: Delhi
# age: 20
#
# Example 5: Mixing All Types
# ----- Student Information -----
# Name: Aman
# Course: MCA
#
# Skills (*args):
# - C
# - C++
# - Python
#
# Additional Details (**kwargs):
# city: Patna
# age: 21
# ...
